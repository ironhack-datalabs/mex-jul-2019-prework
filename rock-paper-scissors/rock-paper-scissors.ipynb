# %% [markdown]
# # Rock Paper Scissors
#
# Let's play the famous game against our computer.
#
# https://en.wikipedia.org/wiki/Rock%E2%80%93paper%E2%80%93scissors
#
# The use of functions is recommended
#
# ## Goals
# 1. Use of loop
# 2. Data capture by console
# 3. Use if-elif-else
# 4. Use of try-except
# 5. Definition of functions. Modular programming
# 6. Logical operators.
# 7. Print
# 8. Import modules

# %%
# Import the choice function of the random module
# https://stackoverflow.com/questions/306400/how-to-randomly-select-an-item-from-a-list

import random

game = ["stone","paper","scissors"]

m = 5
w = 3

def computer_play():
    comp_play = random.choice(["stone","paper","scissors"])
    return comp_play

def user_play():
    a = input("Choose 'stone', 'paper' or 'scissors':\n")
    if a == "stone" or a == "paper" or a == "scissors":
        return a
    else:
        print("Choose from the following options: 'stone', 'paper' or 'scissors'.\n")
        a = input("Choose 'stone', 'paper' or 'scissors':\n")

user_choice = 0
computer_choice = 0

def match(a,b):
    a = user_play()
    b = computer_play()
    print("\nUser's choice: %s \nComputer's choice: %s" % (a,b))
    if a == b :
        print("\nIt's a tie")
        return 0
    elif b == "stone" and a == "scissors":
        print ("\nComputer wins")
        return 1
    elif b == "paper" and a == "stone":
        print ("\nComputer wins")
        return 1
    elif b == "scissors" and a == "paper":
        print ("\nComputer wins")
        return 1
    else:
        print("\nUser wins")
        return 2
    

w_comp = 0
w_user = 0
matches = 0

while matches <= m:
    print("\nLet's start a new Rock-Paper-Scissors match.")
    result = match(user_choice, computer_choice)
    if result == 0:
        matches += 1
    elif result == 1:
        w_comp += 1
        matches += 1
    elif result == 2:
        w_user += 1
        matches += 1
    if w_comp == w:
        print("\nComputer wins :)\nComputer: %s \nPlayer: %s" % (w_comp,w_user))
    elif w_user == w:
        print("\nUser wins :)\nPlayer: %s \nComputer: %s" % (w_user,w_comp))
    if w_user == 3 or w_comp == 3:
        break
    elif matches == m:
        print("\nComputer: %s \nPlayer: %s \nNobody won. Good Game!" % (w_user,w_comp))
        break
# Out:
# Let's start a new Rock-Paper-Scissors match.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/Cellar/ipython/7.5.0/libexec/vendor/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     877             try:
# --> 878                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     879             except Exception:
#
# /usr/local/Cellar/ipython/7.5.0/libexec/vendor/lib/python3.7/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/Cellar/ipython/7.5.0/libexec/vendor/lib/python3.7/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     469         """
# --> 470         parts = [self.recv(flags, copy=copy, track=track)]
#     471         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/Cellar/ipython/7.5.0/libexec/vendor/lib/python3.7/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-74c9ad8d3da3> in <module>
#      51 while matches <= m:
#      52     print("\nLet's start a new Rock-Paper-Scissors match.")
# ---> 53     result = match(user_choice, computer_choice)
#      54     if result == 0:
#      55         matches += 1
#
# <ipython-input-1-74c9ad8d3da3> in match(a, b)
#      25
#      26 def match(a,b):
# ---> 27     a = user_play()
#      28     b = computer_play()
#      29     print("\nUser's choice: %s \nComputer's choice: %s" % (a,b))
#
# <ipython-input-1-74c9ad8d3da3> in user_play()
#      14
#      15 def user_play():
# ---> 16     a = input("Choose 'stone', 'paper' or 'scissors':\n")
#      17     if a == "stone" or a == "paper" or a == "scissors":
#      18         return a
#
# /usr/local/Cellar/ipython/7.5.0/libexec/vendor/lib/python3.7/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     851             self._parent_ident,
#     852             self._parent_header,
# --> 853             password=False,
#     854         )
#     855
#
# /usr/local/Cellar/ipython/7.5.0/libexec/vendor/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     881             except KeyboardInterrupt:
#     882                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 883                 raise KeyboardInterrupt
#     884             else:
#     885                 break
#
# KeyboardInterrupt:

# %% [markdown]
# # Bonus: Stone, paper, scissors, lizard, spock
#
# Now the improvement begins.
#
# ![](images/rpsls.jpg)
#
#
# http://www.samkass.com/theories/RPSSL.html
#
# You are asked to impliment some improvements with respect to the simple previous game. In addition, the number of games (which must be ODD) will be requested per console until a valid number is entered.
#
# Improvements:
# * 5 options: stone, paper, scissors, lizard, spock
# * The number of games is requested per console
# Tip: Reuse code that you already use. If you have programmed intelligently, the bonus are simple modifications to the original game.

# %%
# Import the choice function of the random module

import random

game = ["stone","paper","scissors","lizard","spock"]


def odd_plays():
    number = int(input("Choose an odd number of plays for the match:"))
    while number % 2 == 0:
        print("You chose and even number. Please choose again.")
        number = int(input("Choose an odd number of plays for the match:"))
    return number

def computer_play():
    comp_play = random.choice(["stone","paper","scissors", "lizard","spock"])
    return comp_play

def user_play():
    a = input("Choose 'stone', 'paper', 'scissors', 'lizard' or 'spock':\n")
    if a == "stone" or a == "paper" or a == "scissors" or a == "lizard" or a == "spock":
        return a
    else:
        print("Choose from the following options: 'stone', 'paper', 'scissors', 'lizard' or 'spock'.\n")
        a = input("Choose 'stone', 'paper', 'scissors', 'lizard' or 'spock':\n")

user_choice = 0
computer_choice = 0

def match(a,b):
    a = user_play()
    b = computer_play()
    print("\nUser's choice: %s \nComputer's choice: %s" % (a,b))
    if a == b :
        print("\nIt's a tie")
        return 0
    elif b == "stone" and a == "scissors" or a == "lizard":
        print ("\nComputer wins")
        return 1
    elif b == "paper" and a == "stone" or a == "spock":
        print ("\nComputer wins")
        return 1
    elif b == "scissors" and a == "paper" or a == "lizard":
        print ("\nComputer wins")
        return 1
    elif b == "lizard" and a == "paper" or a == "spock":
        print ("\nComputer wins")
        return 1
    elif b == "spock" and a == "stone" or a == "scissors":
        print ("\nComputer wins")
        return 1
    else:
        print("\nUser wins")
        return 2
    

w_comp = 0
w_user = 0
matches = 0

m = odd_plays()
w = (m + 1)/2
while matches <= m:
    print("\nLet's start a new Rock-Paper-Scissors-Lizard-Spock match.")
    result = match(user_choice, computer_choice)
    if result == 0:
        matches += 1
    elif result == 1:
        w_comp += 1
        matches += 1
    elif result == 2:
        w_user += 1
        matches += 1
    if w_comp == w:
        print("\nComputer wins :)\nComputer: %s \nPlayer: %s" % (w_comp,w_user))
    elif w_user == w:
        print("\nUser wins :)\nPlayer: %s \nComputer: %s" % (w_user,w_comp))
    if w_user == 3 or w_comp == 3:
        break
    elif matches == m:
        print("\nComputer: %s \nPlayer: %s \nNobody won. Good Game!" % (w_user,w_comp))
        break
# Out:
# Choose an odd number of plays for the match:6
# You chose and even number. Please choose again.
# Choose an odd number of plays for the match:8
# You chose and even number. Please choose again.
# Choose an odd number of plays for the match:5
#
# Let's start a new Rock-Paper-Scissors-Lizard-Spock match.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/Cellar/ipython/7.5.0/libexec/vendor/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     877             try:
# --> 878                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     879             except Exception:
#
# /usr/local/Cellar/ipython/7.5.0/libexec/vendor/lib/python3.7/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/Cellar/ipython/7.5.0/libexec/vendor/lib/python3.7/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     469         """
# --> 470         parts = [self.recv(flags, copy=copy, track=track)]
#     471         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/Cellar/ipython/7.5.0/libexec/vendor/lib/python3.7/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-2b46e999731f> in <module>
#      63 while matches <= m:
#      64     print("\nLet's start a new Rock-Paper-Scissors-Lizard-Spock match.")
# ---> 65     result = match(user_choice, computer_choice)
#      66     if result == 0:
#      67         matches += 1
#
# <ipython-input-6-2b46e999731f> in match(a, b)
#      29
#      30 def match(a,b):
# ---> 31     a = user_play()
#      32     b = computer_play()
#      33     print("\nUser's choice: %s \nComputer's choice: %s" % (a,b))
#
# <ipython-input-6-2b46e999731f> in user_play()
#      18
#      19 def user_play():
# ---> 20     a = input("Choose 'stone', 'paper', 'scissors', 'lizard' or 'spock':\n")
#      21     if a == "stone" or a == "paper" or a == "scissors" or a == "lizard" or a == "spock":
#      22         return a
#
# /usr/local/Cellar/ipython/7.5.0/libexec/vendor/lib/python3.7/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     851             self._parent_ident,
#     852             self._parent_header,
# --> 853             password=False,
#     854         )
#     855
#
# /usr/local/Cellar/ipython/7.5.0/libexec/vendor/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     881             except KeyboardInterrupt:
#     882                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 883                 raise KeyboardInterrupt
#     884             else:
#     885                 break
#
# KeyboardInterrupt:
